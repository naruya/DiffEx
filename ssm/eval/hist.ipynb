# %%
import matplotlib.pyplot as plt
from eval_utils import Extractor

ext = Extractor("../logzero/Jan31_15-10-46.txt")

# %%
plt.plot(ext("train", "x_loss"))
plt.plot(ext("test", "x_loss"))
plt.show()

# %%
plt.plot(ext("train", "s_loss"))
plt.plot(ext("test", "s_loss"))
plt.ylim([0, 20])
plt.show()

# %%
plt.plot(ext("train", "s_aux_loss"))
plt.plot(ext("test", "s_aux_loss"))
plt.show()
